# %% [markdown]
# <a href="https://colab.research.google.com/github/MicaSuarez915/Tesis_scrapping_ml/blob/main/Machine_Learning_Tesis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Script de configuración del entorno para procesamiento de sentencias laborales
Tesis LexGO
"""

# Instalación de dependencias necesarias
print("📦 Instalando dependencias...")

# Para ejecutar en Colab/Jupyter, descomenta estas líneas:
# !pip install pypdf2 --break-system-packages
# !pip install beautifulsoup4 --break-system-packages
# !pip install lxml --break-system-packages
# !pip install pandas --break-system-packages
# !pip install scikit-learn --break-system-packages

import os
from pathlib import Path

# Estructura de directorios
DIRS = {
    'raw_data': 'data/raw',           # Sentencias descargadas
    'processed': 'data/processed',     # Datos procesados
    'models': 'models',                # Modelos entrenados
    'results': 'results'               # Resultados y métricas
}

# Crear estructura de carpetas
print("\n📁 Creando estructura de directorios...")
for name, path in DIRS.items():
    Path(path).mkdir(parents=True, exist_ok=True)
    print(f"✓ {path}")

print("\n✅ Entorno configurado correctamente")
print("\nPróximos pasos:")
print("1. Coloca tus sentencias descargadas en: data/raw/")
print("2. Ejecuta el script de parseo (próximo paso)")
